# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
data = pd.read_csv('baseball.csv')

# %%
# Top 5 rows of dataset
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Check the dimensions of dataset
data.shape
# Out:
# (30, 17)

# %%
# Check the datatypes of dataset
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# No Categorical data to be converted into numeric data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Check the column names
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Based om our requirement we change the columns names
data = data.rename(columns = {'W' : 'Wins', 'R' : 'Runs', 'AB' : 'At Bats', 'H' : 'Hits', '2B' : 'Doubles', '3B' : 'Triples', 'HR' : 'Homeruns', 'BB' : 'Walks', 'SO' : 'Strikeouts', 'SB' : 'Stolen Bases', 'RA' : 'Runs Allowed', 'ER' : 'Earned Runs', 'ERA' : 'Earned Run Average', 'CG' : 'Complete Games', 'SHO' :'Shutouts', 'SV' : 'Saves', 'E' : 'Errors'})

# %%
data
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42       139    383         973
# 1     83   696     5467  1349      277       44       156    439        1264
# 2     81   669     5439  1395      303       29       141    533        1157
# 3     76   622     5533  1381      260       27       136    404        1231
# 4     74   689     5605  1515      289       49       151    455        1259
# 5     93   891     5509  1480      308       17       232    570        1151
# 6     87   764     5567  1397      272       19       212    554        1227
# 7     81   713     5485  1370      246       20       217    418        1331
# 8     80   644     5485  1383      278       32       167    436        1310
# 9     78   748     5640  1495      294       33       161    478        1148
# 10    88   751     5511  1419      279       32       172    503        1233
# ...

# %%
# Statistical information of dataset
data.describe()
# Out:
#              Wins        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# Observation:
#
# Except Earned Run Average (ERA) and Complete Games (CG), all other columns have higher mean and Standard deviation. Given data is not standard and uneven, it can be regularized later for the model to understand it better.

# %%
# Checking missing values 
data.isnull().sum()
# Out:
# Wins                  0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Complete Games        0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# Observation:
#
# No Null or missing values to be handled.

# %% [markdown]
# ## Data Visualization

# %%
data.columns
# Out:
# Index(['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
# Checking the distribution values of each column
columns = ['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
       'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
       'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors']
for i in data[columns]:
    plt.figure()
    sns.distplot(data[i])

# %%
columns = ['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
       'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
       'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors']
for i in data[columns]:
    plt.figure()
    sns.countplot(data[i])

# %% [markdown]
# Observation:
#
# Target variable data is not imbalanced.

# %%
sns.jointplot(x='Runs', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Runs are directly proportional to Wins

# %%
sns.jointplot(x='Saves', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Saves are directly proportional to Wins

# %%
sns.jointplot(x='Errors', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Errors are inversly proportional to Wins

# %%
sns.jointplot(x='Doubles', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Doubles are directly proportional to Wins

# %%
sns.jointplot(x='Triples', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Triples are inversly proportional to Wins

# %%
sns.jointplot(x='Earned Runs', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Earned Runs are inversly proportional to Wins

# %%
sns.jointplot(x='Earned Run Average', y= 'Wins', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Earned Run Average is inversly proportional to Wins

# %%
sns.jointplot(x='Earned Runs', y= 'Earned Run Average', data=data, height=10, ratio=3, color='blue', kind="reg")
plt.show()

# %% [markdown]
# Earned Run Average is directly proportional to Earned Runs

# %%
sns.pairplot(data)

# %%
data.plot(kind='density', subplots=True, layout=(6, 11), sharex=False, legend=False, fontsize=1, figsize=(10, 8))
plt.show()

# %% [markdown]
# Observation:
#
# From above density plot curve, we can see only some skewness in few graphs

# %% [markdown]
# ## Checking Outliers

# %%
# Remove outliers before skewness check and befor x, y split

data.boxplot(figsize=[20, 8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
# Removing outliers by using z-score method
from scipy.stats import zscore
z  =np.abs(zscore(data))
df = data[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (29, 17)

# %%
dataloss = ((30-29)/30)*100
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# Outliers are not removed since available data is very less.

# %% [markdown]
# ## Correlation and heatmap

# %%
plt.figure(figsize=[22, 12])
corr=data.corr()
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# Arrange correlation in descending order. Droping columns should be the last option to prevent data loss.

# %%
corr["Wins"].sort_values(ascending=False)
# Out:
# Wins                  1.000000
# Saves                 0.666530
# Walks                 0.484342
# Shutouts              0.471805
# Runs                  0.430751
# Doubles               0.427797
# Homeruns              0.307407
# Strikeouts            0.111850
# Complete Games        0.080533
# Hits                  0.037612
# At Bats              -0.087947
# Errors               -0.089485
# Stolen Bases         -0.157234
# Triples              -0.251118
# Earned Runs          -0.809435
# Runs Allowed         -0.812952
# Earned Run Average   -0.819600
# Name: Wins, dtype: float64

# %% [markdown]
# ## Check for skewness

# %%
data.skew()
# Out:
# Wins                  0.047089
# Runs                  1.200786
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Complete Games        0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %% [markdown]
# We can clearly visualize the data by using Histogram plotting i,e, distplot. since it show, if any skewness

# %%
data_hist=data.columns.values
plt.figure(figsize=(8, 14))
for i in range(0, len(data_hist)):
    sns.distplot(data[data_hist[i]], color='green')
    plt.show()

# %% [markdown]
# Observations:
#
# 1.Distplot shows there is No Skewwness.
# 2.given data is not skewwed and don't have outliers.
# 3.The Target is clearly continous type.It should dealt with linear regression while testing the model.
# 4.Data is not normal as it has irregular mean and standard deviation

# %% [markdown]
# ## Split the data and then independent variables are to be normalized

# %%
x = data.iloc[:, 1:]
y = data.iloc[:, 0]

# %%
y = y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (30, 1)

# %%
x.skew()
# Out:
# Runs                  1.200786
# At Bats               0.183437
# Hits                  0.670254
# Doubles              -0.230650
# Triples               0.129502
# Homeruns              0.516441
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Complete Games        0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %%
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %% [markdown]
# Let's take the threshold skewness to be 0.5 Log transformation is applied to remove the skewness.

# %%
x.skew()
# Out:
# Runs                  0.744813
# At Bats               0.183437
# Hits                  0.628584
# Doubles              -0.230650
# Triples               0.129502
# Homeruns             -0.009528
# Walks                 0.158498
# Strikeouts           -0.156065
# Stolen Bases          0.479893
# Runs Allowed          0.045734
# Earned Runs           0.058710
# Earned Run Average    0.053331
# Complete Games       -0.325962
# Shutouts             -0.093545
# Saves                 0.163057
# Errors                0.632916
# dtype: float64

# %% [markdown]
# Skewness is Removed

# %% [markdown]
# ## Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
pd.DataFrame(x)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.665329  0.847731  1.649382  1.420173  1.041193 -0.763978 -1.534902
# 1   0.179562 -0.711094 -0.981656  0.127403  1.235809 -0.157077 -0.536592
# 2  -0.307704 -1.115233 -0.134210  1.588795 -0.223808 -0.688861  1.139144
# 3  -1.204730  0.241522 -0.389136 -0.828122 -0.418423 -0.878690 -1.160536
# 4   0.055070  1.280738  1.951480  0.801892  1.722347 -0.328473 -0.251360
# 5   3.221983 -0.104884  1.360715  1.869832 -1.391501  1.933613  1.798742
# 6   1.327687  0.732263 -0.098001 -0.153633 -1.196885  1.458347  1.513510
# 7   0.476767 -0.451289 -0.591253 -1.615025 -1.099578  1.581221 -0.910958
# 8  -0.776713 -0.451289 -0.352560  0.183611  0.068115  0.201536 -0.590073
# 9   1.066997  1.785913  1.615591  1.082929  0.165423  0.008945  0.158660
# 10  1.116298 -0.076017  0.296915  0.239818  0.068115  0.356845  0.604334
# 11  0.750096 -0.826562 -0.720719  0.183611 -0.515731  1.887960  0.301276
# ...

# %% [markdown]
# Standard Scaler has brought the data into single scale where it is easy to the model to understand the data.

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=24)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train, y_train)
print('Coefficients: \n', LR.coef_)

predictions = LR.predict(x_test)
plt.scatter(y_test, predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('Variance:', metrics.explained_variance_score(y_test, predictions))
# Out:
# Coefficients:
#  [[  4.47735587   0.44898126   0.8379507    0.14884378   0.34979967
#    -1.43201287  -3.42241821   1.75364427  -0.19194938   7.23979055
#   -15.80957252   3.38722651   2.16830534   3.12455346   5.50279392
#    -1.30555797]]
# MAE: 7.305242239132519
# MSE: 65.25959297650233
# RMSE: 8.07834097921735
# Variance: 0.04545069054285167

# %%
print('Train Score', LR.score(x_train, y_train))
print('Test Score', LR.score(x_test, y_test))
# Out:
# Train Score 0.9882895036898574
# Test Score -0.012648856531932706

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
LR_cv = cross_val_score(LinearRegression(), x, y, cv=5)
print(LR_cv)
print(LR_cv.mean()*100, LR_cv.std())
# Out:
# [ 0.69348027 -3.03388939  0.57756892  0.67596651  0.24924174]
# -16.752638840054313 1.4420618767871702

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Lasso, Ridge
ls = Lasso(alpha=0.00001)
ls.fit(x_train, y_train)
ls.score(x_train, y_train)
# Out:
# 0.9881550513405202

# %%
ls.coef_
# Out:
# array([ 4.81549962e+00,  4.63755372e-01,  6.40089623e-01,  8.84237377e-03,
#         3.41263640e-01, -1.84408716e+00, -3.01549732e+00,  1.79976252e+00,
#        -1.78843905e-01,  4.60462470e+00, -9.38746342e+00, -5.24807754e-01,
#         2.08966571e+00,  2.77209761e+00,  5.28125455e+00, -1.33367733e+00])

# %%
rd = Ridge(alpha=0.00001)
rd.fit(x_train, y_train)
rd.score(x_train, y_train)
# Out:
# 0.988289500999118

# %%
rd.coef_
# Out:
# array([[  4.47895646,   0.44775294,   0.8378014 ,   0.14812121,
#           0.34987986,  -1.43347241,  -3.42080909,   1.75356416,
#          -0.19188419,   7.23108234, -15.7764751 ,   3.36236074,
#           2.16790655,   3.12308259,   5.50175399,  -1.30542136]])

# %%
from sklearn.linear_model import ElasticNet
Enr = ElasticNet(alpha=0.00001)
Enr.fit(x_train, y_train)
Enr.score(x_train, y_train)
# Out:
# 0.9881543113307095

# %%
Enr.coef_
# Out:
# array([ 4.81626440e+00,  4.62787459e-01,  6.40134674e-01,  8.38503438e-03,
#         3.41408579e-01, -1.84479539e+00, -3.01419969e+00,  1.79959559e+00,
#        -1.78793416e-01,  4.59888592e+00, -9.36373395e+00, -5.43178368e-01,
#         2.08926332e+00,  2.77095225e+00,  5.28044580e+00, -1.33354080e+00])

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(max_depth=5)
DTR.fit(x_train, y_train)

predictions = DTR.predict(x_test)

plt.scatter(y_test, predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print('Variance:', metrics.explained_variance_score(y_test, predictions))
# Out:
# MAE: 9.88888888888889
# MSE: 133.66666666666666
# RMSE: 11.561430130683084
# Variance: -0.8900383141762453

# %% [markdown]
# ## Cross Validation

# %%
DTR_cv = cross_val_score(DecisionTreeRegressor(), x, y, cv=5)
print(DTR_cv)
print(DTR_cv.mean()*100, DTR_cv.std())
# Out:
# [-2.4928952  -9.07633588 -0.41089109  0.39152276  0.56686391]
# -220.43471005915202 3.603945754751598

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

model = DecisionTreeRegressor()

gs = GridSearchCV(model,
                  param_grid = {'max_depth': range(1, 11),
                                'min_samples_split': range(10, 60, 10)},
                  cv=5,
                  n_jobs=1,
                  scoring='neg_mean_squared_error')

gs.fit(x_train, y_train)

print(gs.best_params_)
print(-gs.best_score_)
# Out:
# {'max_depth': 1, 'min_samples_split': 10}
# 86.12321355920315

# %%
print('Train Score', DTR.score(x_train, y_train))
print('Test Score', DTR.score(x_test, y_test))
# Out:
# Train Score 1.0
# Test Score -1.0741379310344827

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
RFR = RandomForestRegressor(n_estimators = 100)
RFR.fit(x_train, y_train)
print('Train Score', RFR.score(x_train, y_train))
print('Test Score', RFR.score(x_test, y_test))
# Out:
# Train Score 0.9613895357196913
# Test Score -0.022273275862069397

# %% [markdown]
# ## Cross Validation

# %%
RFR_cv = cross_val_score(RandomForestRegressor(), x, y, cv=5)
print(RFR_cv)
print(RFR_cv.mean()*100, RFR_cv.std())
# Out:
# [ 0.30654414 -4.48192061  0.22567487  0.2800437   0.70385935]
# -59.31597102894148 1.951776681142578

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
RFR = RandomForestRegressor()

gs = GridSearchCV(RFR,
                  param_grid = {'max_depth': range(1, 11),
                                'min_samples_split': range(10, 60, 10)},
                  cv=5,
                  n_jobs=1,
                  scoring='neg_mean_squared_error')

gs.fit(x_train, y_train)

print(gs.best_params_)
print(-gs.best_score_)
# Out:
# {'max_depth': 8, 'min_samples_split': 10}
# 62.205964441423035

# %% [markdown]
# Decision Tree Regressor seems to have better score.

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(DTR, "DTR.pkl")
# Out:
# ['DTR.pkl']
